# %%
buffer = "jU5t_a_sna_3lpm15g64e_u_4_m1r74d"
flag = list(buffer)
for i in range(0,8):
    flag[i] = buffer[i]
for i in range(8,16):
    flag[23-i] = buffer[i]
for i in range(16,32,2):
    flag[46-i] = buffer[i]
for i in range(17,32,2):
    flag[i] = buffer[i]
print("Flag is: picoCTF{%s}" % ''.join(flag))
# Out:
# Flag is: picoCTF{jU5t_a_s1mpl3_an4gr4m_4_u_e1675d}
