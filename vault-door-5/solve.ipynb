# %%
import base64
from urllib.parse import unquote
password = ["JTYzJTMwJTZlJTc2JTMzJTcyJTc0JTMxJTZlJTY3JTVm", "JTY2JTcyJTMwJTZkJTVmJTYyJTYxJTM1JTY1JTVmJTM2"
, "JTM0JTVmJTM3JTY2JTM4JTM1JTM1JTY2JTYzJTM1"]

flag = ""
for word in password:
    key = base64.b64decode(word)
    flag = flag + unquote(key.decode("utf-8"))
print(flag)
# Out:
# c0nv3rt1ng_fr0m_ba5e_64_7f855fc5
