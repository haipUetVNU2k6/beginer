# %%
myBytes = bytes([
            0x3b, 0x65, 0x21, 0xa , 0x38, 0x0 , 0x36, 0x1d,
            0xa , 0x3d, 0x61, 0x27, 0x11, 0x66, 0x27, 0xa ,
            0x21, 0x1d, 0x61, 0x3b, 0xa , 0x2d, 0x65, 0x27,
            0xa , 0x37, 0x67, 0x6d, 0x6c, 0x30, 0x30, 0x37,
 ])
flag = ""
for byte in myBytes:
   flag = flag + chr(byte^0x55)
print(f"flag is : picoCTF{{{flag}}}")
# Out:
# flag is : picoCTF{n0t_mUcH_h4rD3r_tH4n_x0r_b289eeb}
