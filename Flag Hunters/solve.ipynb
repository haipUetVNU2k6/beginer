# %% [markdown]
# Đọc và phân tích , ta chú ý đoạn nhập input vào, refrain chỉ cần nhập nội dung một làn và từ lần thứ 2 nó nhắc lại tự động.
#
# Điều ta muốn là gì?Chúng ta cần chèn một cái return 0 và một cách duy nhất là dựa vào lần nhập input nhưng làm thế nào để đoạn chèn đó được xử lý chứ không phải chỉ in
#
# --> Cách duy nhất là ta phải chèn đoạn sau : attack;RETURN 0 , attack có thể thay bằng bất kì ký tự nào.
