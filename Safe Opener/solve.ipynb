# %% [markdown]
# Nhận xét: DDee

# %%
cipher = 'cGwzYXMzX2wzdF9tM18xbnQwX3RoM19zYWYz'
import base64
flag = base64.b64decode(cipher)
print(b'passowrd:%s',flag)
# Out:
# b'passowrd:%s' b'pl3as3_l3t_m3_1nt0_th3_saf3'
