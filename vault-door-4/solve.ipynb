# %%
myBytes = bytes([ 106 , 85  , 53  , 116 , 95  , 52  , 95  , 98  ,
            0x55, 0x6e, 0x43, 0x68, 0x5f, 0x30, 0x66, 0x5f,
            98, 89, 116, 51, 115, 95, 49, 50,
            ord('6') , ord('5') , ord('3') , ord('7') , ord('5') , ord('3') , ord('9') , ord('2') ,])
res = ""
for byte in myBytes:
    res = res + chr(byte)
print("flag is : picoCTF{%s}" %res)
# Out:
# flag is : picoCTF{jU5t_4_bUnCh_0f_bYt3s_1265375392}
