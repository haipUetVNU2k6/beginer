# %% [markdown]
# Qua src code ta thấy phương thức boolean để kiểm tra mật khẩu nếu đúng thì 'Access granted', nghĩa là thành công .Vậy dễ dàng thấy picoCTF{w4rm1ng_Up_w1tH_jAv4_000uMfhzBuS} là flag cần tìm.
