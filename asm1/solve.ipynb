# %% [markdown]
# 1.Xác định đây là ngôn ngữ asm x86 hay x86_64:
# - endbr32 --> 32 bit và ta thấy không có thanh ghi nào bắt đầu bằng 'r' --> 32 bit
# --> return value được lưu ở thanh ghi eax
# 2.Đọc luồng:
# - Đặt x = [ebp + 0x8]
# - Ta thực hiện brute-force và phát hiện chỉ có case x = 878(decimal) là thỏa mãn mã và đồng thời các path còn lại không thể xác định nổi x cụ thể
# - Ta đọc luồng với x = 878 --> ta có return value(%eax) = 0x374
# 3.Lưu ý: bài này không có format picoCTF , nghĩa là chỉ cần submit: 0x374
