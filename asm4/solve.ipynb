# %%
from Crypto.Util.number import bytes_to_long

def convert(arg):
    b = arg.encode('utf-8')
    return b
arg = "picoCTF_e53f9\0"
x = int('0x267',16)
y = 0
eax = 0
i = 0
while True:
    edx = y
    eax = i
    eax = eax + edx
    eax = bytes_to_long(convert(arg[eax]))
    
    if (eax & 0xff) & (eax & 0xff) == 0:
        break
    y = y + 1
z = 1

while True:
    eax = y
    eax = eax - 1
    if z >= eax:
        break

    edx = z
    eax = i
    eax = eax +edx
    eax = bytes_to_long(convert(arg[eax])) & 0xff
    
    edx = eax & 0xff
    eax = z
    ecx = eax - 1
    eax = i
    eax = eax + ecx
    eax = bytes_to_long(convert(arg[eax])) & 0xff
    eax = eax & 0xff
    edx = edx - eax
    eax = edx
    edx = eax
    eax = x
    ebx = edx + eax*1
    eax = z
    edx = eax + 1
    eax = i
    eax = eax + edx
    eax = bytes_to_long(convert(arg[eax])) & 0xff
    edx = eax & 0xff
    ecx =  z
    eax = i
    eax = eax + ecx
    eax = bytes_to_long(convert(arg[eax])) & 0xff
    eax = eax & 0xff
    edx = edx - eax
    eax = edx
    eax = eax + ebx
    x = eax
    z = z +1
    
eax = x

print(hex(eax))
# Out:
# 0x22d
